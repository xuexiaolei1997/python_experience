# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# like fft
x = np.linspace(-np.pi*7, np.pi*7, 300)
plt.plot(x, np.sin(x)+(1/3)*np.sin(3*x)+(1/5)*np.sin(5*x)+(1/7)*np.sin(7*x)+(1/9)*np.sin(9*x)+(1/11)*np.sin(11*x))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
